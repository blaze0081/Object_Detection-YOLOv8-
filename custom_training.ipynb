# %%
# !nvidia-smi
# Out:
# Mon Jul  3 00:01:58 2023
# +-----------------------------------------------------------------------------+
# | NVIDIA-SMI 525.116.04   Driver Version: 525.116.04   CUDA Version: 12.0     |
# |-------------------------------+----------------------+----------------------+
# | GPU  Name        Persistence-M| Bus-Id        Disp.A | Volatile Uncorr. ECC |
# | Fan  Temp  Perf  Pwr:Usage/Cap|         Memory-Usage | GPU-Util  Compute M. |
# |                               |                      |               MIG M. |
# |===============================+======================+======================|
# |   0  NVIDIA GeForce ...  Off  | 00000000:01:00.0  On |                  N/A |
# | N/A   60C    P8    12W /  60W |     46MiB /  4096MiB |     21%      Default |
# |                               |                      |                  N/A |
# +-------------------------------+----------------------+----------------------+
#
# ...

# %%
# !pip install ultralytics

# %%
from ultralytics import YOLO
# Out:
# WARNING ⚠️ Ultralytics settings reset to defaults. This is normal and may be due to a recent ultralytics package update, but may have overwritten previous settings.
# View and update settings with 'yolo settings' or at '/home/bhaskar/.config/Ultralytics/settings.yaml'

# %%
# !yolo task=detect mode=train model=yolov8n.pt data=data/ANI_DATA.v3i.yolov8/data.yaml epochs=50 imgsz=640
# Out:
# Ultralytics YOLOv8.0.124 🚀 Python-3.10.9 torch-2.0.1+cu117 CUDA:0 (NVIDIA GeForce RTX 3050 Laptop GPU, 3902MiB)
# ...
